# %%
import os

os.environ['OPENAI_API_KEY']="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"

# %%
from langchain.llms import OpenAI
llm = OpenAI(temperature = 0.7)

# %%
from langchain.prompts import PromptTemplate

prompt_template_class_name=PromptTemplate(
    input_variables=['class_name'],
    template="you are the alcohol mafia you explain using funny examples whatever input is given you explain {class_name} in mafia style also make it in hindi "
    
)
#prompt_template_class_name.format(class_name="class 10")

# %%
from langchain.chains import LLMChain

chain1=LLMChain(llm=llm,prompt=prompt_template_class_name)
f=chain1.run("porn")

# %%
from gtts import gTTS
from IPython.display import Audio
import io  # Make sure you import the io module

def text_to_speech(text):
    language = 'en'  # English, change it to another language if you want!

    # Passing the text and language to the engine
    speech = gTTS(text=text, lang=language, slow=False)

    # Save to BytesIO object
    with io.BytesIO() as f:
        speech.write_to_fp(f)
        f.seek(0)
        audio = Audio(f.read(), autoplay=True)

    return audio

# Text to convert to speech
text = f

audio_output = text_to_speech(text)
display(audio_output)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
